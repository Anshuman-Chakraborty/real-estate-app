# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../processed_data/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                         society      sector  price  \
# 0          flat                 dlf the belaire   sector 54  10.00
# 1          flat              imperia the esfera  sector 37c   0.95
# 2         house                     independent    sector 3   0.60
# 3         house  u block dlf phase 3 road no 21   sector 24   1.60
# 4          flat                     mrg skyline  sector 106   1.82
#
#    price_per_sq_ft                      area  \
# 0          24557.0         4072.158651301055
# 1           5703.0        1665.7899351218657
# 2           6000.0  (93 sq.m.) Built-up Area
# 3          29630.0      (50 sq.m.) Plot Area
# 4          13392.0         1359.020310633214
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4072(378.3 sq.m.)Built Up ...      4.0       5.0
# 1                  Built Up area: 1578 (146.6 sq.m.)      2.0       2.0
# 2                   Built Up area: 1000 (92.9 sq.m.)      1.0       1.0
# 3                          Plot area 60(50.17 sq.m.)      7.0       5.0
# 4  Built Up area: 1359 (126.26 sq.m.)Carpet area:...      3.0       2.0
#
#   balcony  floorNum facing       agePossession  super_built_up_area  \
# 0      3+      17.0  North      Moderately Old               4072.0
# 1       0      17.0    NaN  Under Construction                  NaN
# 2       0       1.0    NaN           Undefined                  NaN
# 3      3+       4.0    NaN        Old Property                  NaN
# 4       2       4.0   East           Undefined                  NaN
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0         3000.0       2800.0           0             1           0
# 1         1578.0          NaN           0             1           0
# 2         1000.0          NaN           0             0           0
# 3           60.0          NaN           0             0           0
# 4         1359.0        952.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1           167
# 1           0       0                0            66
# 2           0       0                0             0
# 3           0       0                0             0
# 4           0       0                0             0

# %% [markdown]
# ### **property_type vs price**

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### **property_type vs area**

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### **property_type vs price_per_sq_ft**

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sq_ft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sq_ft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sq_ft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sq_ft'>

# %%
# check outliers
df[df['price_per_sq_ft'] > 100000][['property_type','society','sector','price','price_per_sq_ft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 285          house         bhim nagar, sector 6   sector 6   0.85
# 309          house                  independent  sector 17   3.50
# 457          house     unitech uniworld resorts  sector 33  10.00
# 513          house                  independent  sector 55   1.45
# 617          house                  independent  sector 23   2.80
# 828          house                        ansal  sector 43   1.85
# 1054         house           vipul tatvam villa  sector 48   7.25
# 1123         house            vatika india next  sector 82   7.00
# 1151         house                  independent  sector 57   8.00
# 1173         house                  independent  sector 28   4.50
# 1178         house                  independent  sector 38   8.00
# 1299         house                  independent  sector 24  10.00
# 1513         house     unitech uniworld resorts  sector 33   9.50
# 1695         house                  independent  sector 54   3.75
# 1714          flat           ambience caitriona  sector 24  14.00
# 1815         house                  independent  sector 12   3.50
# 2093         house         eros rosewood villas  sector 49   2.75
# 2153         house               uppal southend  sector 49   6.75
# 2270         house                dlf the grove  sector 54   5.70
# 2388         house  unitech nirvana birch court  sector 50   7.10
# 2436         house                   ardee city  sector 52   5.50
# 2621         house                  independent   sector 4   0.60
# 2752         house       emaar the palm springs  sector 54  24.00
# 2828         house       unitech deerwood chase  sector 50   8.45
# 2964         house                  independent  sector 12   6.00
# 3018         house                    rk excelo  sector 12   0.60
# 3056         house          huda plot sector 38  sector 38   4.30
# 3270         house       dlf city plots phase 2  sector 25  10.50
# 3328         house       dlf city plots phase 2  sector 25  10.00
#
#       price_per_sq_ft                      area  \
# 285          126865.0       (6 sq.m.) Plot Area
# 309          218750.0  (15 sq.m.) Built-up Area
# 457          181818.0      (51 sq.m.) Plot Area
# 513          241666.0       (6 sq.m.) Plot Area
# 617          161849.0      (16 sq.m.) Plot Area
# 828          308333.0       (6 sq.m.) Plot Area
# 1054         201388.0      (33 sq.m.) Plot Area
# 1123         194444.0      (33 sq.m.) Plot Area
# 1151         266666.0      (28 sq.m.) Plot Area
# 1173         125000.0  (33 sq.m.) Built-up Area
# 1178         230547.0  (32 sq.m.) Built-up Area
# 1299         229885.0    (40 sq.m.) Carpet Area
# 1513         173992.0      (51 sq.m.) Plot Area
# 1695         234375.0      (15 sq.m.) Plot Area
# 1714         200000.0                     700.0
# 1815         133079.0      (24 sq.m.) Plot Area
# 2093         178571.0      (14 sq.m.) Plot Area
# 2153         290948.0      (22 sq.m.) Plot Area
# 2270         211111.0  (25 sq.m.) Built-up Area
# 2388         283333.0      (22 sq.m.) Plot Area
# 2436         183333.0      (28 sq.m.) Plot Area
# 2621         105263.0       (5 sq.m.) Plot Area
# 2752         600000.0      (37 sq.m.) Plot Area
# 2828         235376.0      (33 sq.m.) Plot Area
# 2964         315789.0      (18 sq.m.) Plot Area
# 3018         120000.0       (5 sq.m.) Plot Area
# 3056         245398.0      (15 sq.m.) Plot Area
# 3270         261194.0      (37 sq.m.) Plot Area
# 3328         400000.0      (23 sq.m.) Plot Area
#
#                                            areaWithType  super_built_up_area  \
# 285                            Plot area 67(6.22 sq.m.)                  NaN
# 309                    Built Up area: 160 (14.86 sq.m.)                  NaN
# 457                           Plot area 550(51.1 sq.m.)                  NaN
# 513                            Plot area 60(5.57 sq.m.)                  NaN
# 617   Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 828                            Plot area 60(5.57 sq.m.)                  NaN
# 1054                         Plot area 360(33.45 sq.m.)                  NaN
# 1123  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 1151                         Plot area 300(27.87 sq.m.)                  NaN
# 1173                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 1178  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 1299                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 1513                         Plot area 546(50.73 sq.m.)                  NaN
# 1695                         Plot area 160(14.86 sq.m.)                  NaN
# 1714                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 1815  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2093  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 2153                         Plot area 232(21.55 sq.m.)                  NaN
# 2270                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 2388                          Plot area 240(22.3 sq.m.)                  NaN
# 2436                         Plot area 300(27.87 sq.m.)                  NaN
# 2621                            Plot area 57(5.3 sq.m.)                  NaN
# 2752                         Plot area 400(37.16 sq.m.)                  NaN
# 2828                         Plot area 359(33.35 sq.m.)                  NaN
# 2964  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 3018  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 3056  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 3270                         Plot area 402(37.35 sq.m.)                  NaN
# 3328                         Plot area 250(23.23 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 285            67.0          NaN
# 309           160.0          NaN
# 457           550.0          NaN
# 513            60.0          NaN
# 617           160.0        150.0
# 828            60.0          NaN
# 1054          360.0          NaN
# 1123         3900.0       3743.0
# 1151          300.0          NaN
# 1173          360.0          NaN
# 1178          347.0        215.0
# 1299            NaN        435.0
# 1513          546.0          NaN
# 1695          160.0          NaN
# 1714          700.0          NaN
# 1815         4800.0       4400.0
# 2093            NaN       1650.0
# 2153          232.0          NaN
# 2270          270.0          NaN
# 2388          240.0          NaN
# 2436          300.0          NaN
# 2621           57.0          NaN
# 2752          400.0          NaN
# 2828          359.0          NaN
# 2964            NaN       1600.0
# 3018           30.0         15.0
# 3056          145.0          NaN
# 3270          402.0          NaN
# 3328          250.0          NaN

# %%
df.head()
# Out:
#   property_type                         society      sector  price  \
# 0          flat                 dlf the belaire   sector 54  10.00
# 1          flat              imperia the esfera  sector 37c   0.95
# 2         house                     independent    sector 3   0.60
# 3         house  u block dlf phase 3 road no 21   sector 24   1.60
# 4          flat                     mrg skyline  sector 106   1.82
#
#    price_per_sq_ft                      area  \
# 0          24557.0         4072.158651301055
# 1           5703.0        1665.7899351218657
# 2           6000.0  (93 sq.m.) Built-up Area
# 3          29630.0      (50 sq.m.) Plot Area
# 4          13392.0         1359.020310633214
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4072(378.3 sq.m.)Built Up ...      4.0       5.0
# 1                  Built Up area: 1578 (146.6 sq.m.)      2.0       2.0
# 2                   Built Up area: 1000 (92.9 sq.m.)      1.0       1.0
# 3                          Plot area 60(50.17 sq.m.)      7.0       5.0
# 4  Built Up area: 1359 (126.26 sq.m.)Carpet area:...      3.0       2.0
#
#   balcony  floorNum facing       agePossession  super_built_up_area  \
# 0      3+      17.0  North      Moderately Old               4072.0
# 1       0      17.0    NaN  Under Construction                  NaN
# 2       0       1.0    NaN           Undefined                  NaN
# 3      3+       4.0    NaN        Old Property                  NaN
# 4       2       4.0   East           Undefined                  NaN
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0         3000.0       2800.0           0             1           0
# 1         1578.0          NaN           0             1           0
# 2         1000.0          NaN           0             0           0
# 3           60.0          NaN           0             0           0
# 4         1359.0        952.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1           167
# 1           0       0                0            66
# 2           0       0                0             0
# 3           0       0                0             0
# 4           0       0                0             0

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                    society      sector  price  \
# 59           house  ganpati heights apartment   sector 13   1.25
# 77           house                independent   sector 28    NaN
# 85           house                independent   sector 43  13.50
# 95           house                independent   sector 43   4.50
# 180          house                independent  sector 104   0.80
# ...            ...                        ...         ...    ...
# 3660         house                independent   sector 43   2.20
# 3664         house                independent   sector 11   4.50
# 3671         house                independent  sector 17a   3.87
# 3676         house                independent   sector 46   6.50
# 3765         house                independent   sector 41   4.25
#
#       price_per_sq_ft                    area  \
# 59              151.0  (7692 sq.m.) Plot Area
# 77                NaN   (226 sq.m.) Plot Area
# 85            50000.0   (251 sq.m.) Plot Area
# 95            39062.0   (107 sq.m.) Plot Area
# 180           80000.0     (9 sq.m.) Plot Area
# ...               ...                     ...
# 3660           6875.0   (297 sq.m.) Plot Area
# 3664          25000.0   (167 sq.m.) Plot Area
# 3671           5160.0   (151 sq.m.) Plot Area
# 3676          27461.0   (220 sq.m.) Plot Area
# 3765          26235.0   (151 sq.m.) Plot Area
#
#                                            areaWithType  bedRoom  bathroom  \
# 59                         Plot area 115(7692.86 sq.m.)     10.0       6.0
# 77                          Plot area 270(225.75 sq.m.)     16.0      16.0
# 85                          Plot area 300(250.84 sq.m.)     16.0      16.0
# 95                          Plot area 128(107.02 sq.m.)     20.0      20.0
# 180                           Plot area 100(9.29 sq.m.)     13.0       6.0
# ...                                                 ...      ...       ...
# 3660                       Plot area 3200(297.29 sq.m.)     12.0      12.0
# 3664                        Plot area 200(167.23 sq.m.)     16.0      16.0
# 3671  Plot area 1623(150.78 sq.m.)Built Up area: 750...     19.0      17.0
# 3676                         Plot area 263(219.9 sq.m.)     12.0      12.0
# 3765                         Plot area 180(150.5 sq.m.)     10.0       9.0
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 59         2       3.0  South-East    Old Property                  NaN
# 77        3+       4.0  North-West    New Property                  NaN
# 85        3+       4.0  North-West  Relatively New                  NaN
# 95        3+       4.0        East  Relatively New                  NaN
# 180       3+       3.0       South  Moderately Old                  NaN
# ...      ...       ...         ...             ...                  ...
# 3660      3+       6.0       North    New Property                  NaN
# 3664      3+       4.0       South  Relatively New                  NaN
# 3671      3+       5.0  North-West  Relatively New                  NaN
# 3676      3+       4.0  North-West  Relatively New                  NaN
# 3765      3+       4.0       North  Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 59            115.0          NaN           0             0           0
# 77            270.0          NaN           1             1           0
# 85            300.0          NaN           1             1           0
# 95            128.0          NaN           0             1           0
# 180           100.0          NaN           1             1           0
# ...             ...          ...         ...           ...         ...
# 3660         3200.0          NaN           0             1           0
# 3664          200.0          NaN           0             0           0
# 3671         7500.0          NaN           1             0           1
# 3676          263.0          NaN           1             0           0
# 3765          180.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 59             0       1                0             7
# 77             1       1                0            41
# 85             1       1                0            41
# 95             0       0                1            22
# 180            1       1                0             0
# ...          ...     ...              ...           ...
# 3660           0       0                1            50
# 3664           0       0                2            20
# 3671           0       0                0            68
# 3676           1       0                2            32
# 3765           0       0                2            36
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 546          house              independent   sector 92   1.80
# 639          house   vatika the seven lamps   sector 82   1.60
# 730          house      ireo victory valley   sector 67   8.00
# 976          house           ats tourmaline  sector 109   1.87
# 1347         house      satya the hermitage  sector 103   3.15
# 1364         house              spaze privy   sector 72   3.09
# 1744         house          godrej meridien  sector 106   5.60
# 1978         house  indiabulls centrum park  sector 103   3.25
# 2214         house           dlf the arbour   sector 63   8.50
# 2657         house              spaze privy   sector 72   3.10
# 3208         house              greenopolis   sector 89   0.70
# 3478         house        suncity avenue 76   sector 76   0.75
# 3486         house               ninex city   sector 76   1.75
# 3690         house         suncity township   sector 54   2.00
#
#       price_per_sq_ft                       area  \
# 546            7627.0  (219 sq.m.) Built-up Area
# 639            6597.0      (225 sq.m.) Plot Area
# 730           22222.0      (334 sq.m.) Plot Area
# 976            8697.0  (200 sq.m.) Built-up Area
# 1347           6702.0  (437 sq.m.) Built-up Area
# 1364           6981.0  (339 sq.m.) Built-up Area
# 1744          14000.0      (372 sq.m.) Plot Area
# 1978           8125.0      (372 sq.m.) Plot Area
# 2214          21519.0  (367 sq.m.) Built-up Area
# 2657           8486.0      (339 sq.m.) Plot Area
# 3208           5397.0  (121 sq.m.) Built-up Area
# 3478          10067.0       (69 sq.m.) Plot Area
# 3486           6250.0    (260 sq.m.) Carpet Area
# 3690          30968.0       (60 sq.m.) Plot Area
#
#                                            areaWithType  bedRoom  bathroom  \
# 546                  Built Up area: 2360 (219.25 sq.m.)      4.0       5.0
# 639                        Plot area 2425(225.29 sq.m.)      4.0       4.0
# 730                         Plot area 400(334.45 sq.m.)      6.0       7.0
# 976                  Built Up area: 2150 (199.74 sq.m.)      3.0       4.0
# 1347                 Built Up area: 4700 (436.64 sq.m.)      4.0       5.0
# 1364  Built Up area: 3653 (339.37 sq.m.)Carpet area:...      5.0       5.0
# 1744                       Plot area 4000(371.61 sq.m.)      5.0       4.0
# 1978                       Plot area 4000(371.61 sq.m.)      4.0       3.0
# 2214                 Built Up area: 3950 (366.97 sq.m.)      4.0       4.0
# 2657                       Plot area 3653(339.37 sq.m.)      5.0       5.0
# 3208                  Built Up area: 1297 (120.5 sq.m.)      2.0       2.0
# 3478  Plot area 745(69.21 sq.m.)Built Up area: 745 s...      2.0       2.0
# 3486                   Carpet area: 2800 (260.13 sq.m.)      4.0       4.0
# 3690  Plot area 60Built Up area: 60 sq.m.Carpet area...      9.0       9.0
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 546        0      13.0         NaN           Undefined                  NaN
# 639       3+      16.0       North      Moderately Old                  NaN
# 730       3+      51.0  North-East      Moderately Old                  NaN
# 976        0      12.0         NaN           Undefined                  NaN
# 1347       0      12.0        East           Undefined                  NaN
# 1364      3+      14.0        East      Relatively New                  NaN
# 1744      3+      33.0  North-East        New Property                  NaN
# 1978      3+      20.0         NaN  Under Construction                  NaN
# 2214      3+      27.0         NaN           Undefined                  NaN
# 2657      3+      21.0         NaN      Relatively New                  NaN
# 3208       2      14.0  North-East           Undefined                  NaN
# 3478       2      11.0  North-East        New Property                  NaN
# 3486       0      14.0         NaN           Undefined                  NaN
# 3690       3      11.0       North      Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 546          2360.0          NaN           0             0           0
# 639          2425.0          NaN           0             1           0
# 730           400.0          NaN           1             1           0
# 976          2150.0          NaN           0             0           0
# 1347         4700.0          NaN           0             0           0
# 1364         3653.0       2922.0           0             1           0
# 1744         4000.0          NaN           1             1           1
# 1978         4000.0          NaN           0             0           0
# 2214         3950.0          NaN           0             0           0
# 2657         3653.0          NaN           0             0           0
# 3208         1297.0          NaN           0             0           0
# 3478          745.0          NaN           0             0           0
# 3486            NaN       2800.0           0             0           0
# 3690           60.0         59.0           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 546            0       0                0             0
# 639            0       0                0            94
# 730            1       0                2            49
# 976            0       0                0             0
# 1347           0       0                0            61
# 1364           0       0                2            33
# 1744           1       0                0           151
# 1978           0       0                0            51
# 2214           0       0                0            61
# 2657           0       0                0             0
# 3208           0       0                0             0
# 3478           0       0                0            40
# 3486           0       0                0             0
# 3690           0       0                1             7

# %% [markdown]
# conclusion houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type                         society      sector  price  \
# 0          flat                 dlf the belaire   sector 54  10.00
# 1          flat              imperia the esfera  sector 37c   0.95
# 2         house                     independent    sector 3   0.60
# 3         house  u block dlf phase 3 road no 21   sector 24   1.60
# 4          flat                     mrg skyline  sector 106   1.82
#
#    price_per_sq_ft                      area  \
# 0          24557.0         4072.158651301055
# 1           5703.0        1665.7899351218657
# 2           6000.0  (93 sq.m.) Built-up Area
# 3          29630.0      (50 sq.m.) Plot Area
# 4          13392.0         1359.020310633214
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4072(378.3 sq.m.)Built Up ...      4.0       5.0
# 1                  Built Up area: 1578 (146.6 sq.m.)      2.0       2.0
# 2                   Built Up area: 1000 (92.9 sq.m.)      1.0       1.0
# 3                          Plot area 60(50.17 sq.m.)      7.0       5.0
# 4  Built Up area: 1359 (126.26 sq.m.)Carpet area:...      3.0       2.0
#
#   balcony  floorNum facing       agePossession  super_built_up_area  \
# 0      3+      17.0  North      Moderately Old               4072.0
# 1       0      17.0    NaN  Under Construction                  NaN
# 2       0       1.0    NaN           Undefined                  NaN
# 3      3+       4.0    NaN        Old Property                  NaN
# 4       2       4.0   East           Undefined                  NaN
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0         3000.0       2800.0           0             1           0
# 1         1578.0          NaN           0             1           0
# 2         1000.0          NaN           0             0           0
# 3           60.0          NaN           0             0           0
# 4         1359.0        952.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1           167
# 1           0       0                0            66
# 2           0       0                0             0
# 3           0       0                0             0
# 4           0       0                0             0

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                         society      sector  price  \
# 0          flat                 dlf the belaire   sector 54  10.00
# 1          flat              imperia the esfera  sector 37c   0.95
# 2         house                     independent    sector 3   0.60
# 3         house  u block dlf phase 3 road no 21   sector 24   1.60
# 4          flat                     mrg skyline  sector 106   1.82
#
#    price_per_sq_ft                      area  \
# 0          24557.0         4072.158651301055
# 1           5703.0        1665.7899351218657
# 2           6000.0  (93 sq.m.) Built-up Area
# 3          29630.0      (50 sq.m.) Plot Area
# 4          13392.0         1359.020310633214
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4072(378.3 sq.m.)Built Up ...      4.0       5.0
# 1                  Built Up area: 1578 (146.6 sq.m.)      2.0       2.0
# 2                   Built Up area: 1000 (92.9 sq.m.)      1.0       1.0
# 3                          Plot area 60(50.17 sq.m.)      7.0       5.0
# 4  Built Up area: 1359 (126.26 sq.m.)Carpet area:...      3.0       2.0
#
#   balcony  floorNum facing       agePossession  super_built_up_area  \
# 0      3+      17.0  North      Moderately Old               4072.0
# 1       0      17.0    NaN  Under Construction                  NaN
# 2       0       1.0    NaN           Undefined                  NaN
# 3      3+       4.0    NaN        Old Property                  NaN
# 4       2       4.0   East           Undefined                  NaN
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0         3000.0       2800.0           0             1           0
# 1         1578.0          NaN           0             1           0
# 2         1000.0          NaN           0             0           0
# 3           60.0          NaN           0             0           0
# 4         1359.0        952.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1           167
# 1           0       0                0            66
# 2           0       0                0             0
# 3           0       0                0             0
# 4           0       0                0             0

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sq_ft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sq_ft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type                         society      sector  price  \
# 0          flat                 dlf the belaire   sector 54  10.00
# 1          flat              imperia the esfera  sector 37c   0.95
# 2         house                     independent    sector 3   0.60
# 3         house  u block dlf phase 3 road no 21   sector 24   1.60
# 4          flat                     mrg skyline  sector 106   1.82
#
#    price_per_sq_ft                      area  \
# 0          24557.0         4072.158651301055
# 1           5703.0        1665.7899351218657
# 2           6000.0  (93 sq.m.) Built-up Area
# 3          29630.0      (50 sq.m.) Plot Area
# 4          13392.0         1359.020310633214
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4072(378.3 sq.m.)Built Up ...      4.0       5.0
# 1                  Built Up area: 1578 (146.6 sq.m.)      2.0       2.0
# 2                   Built Up area: 1000 (92.9 sq.m.)      1.0       1.0
# 3                          Plot area 60(50.17 sq.m.)      7.0       5.0
# 4  Built Up area: 1359 (126.26 sq.m.)Carpet area:...      3.0       2.0
#
#   balcony  floorNum facing       agePossession  super_built_up_area  \
# 0      3+      17.0  North      Moderately Old               4072.0
# 1       0      17.0    NaN  Under Construction                  NaN
# 2       0       1.0    NaN           Undefined                  NaN
# 3      3+       4.0    NaN        Old Property                  NaN
# 4       2       4.0   East           Undefined                  NaN
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0         3000.0       2800.0           0             1           0
# 1         1578.0          NaN           0             1           0
# 2         1000.0          NaN           0             0           0
# 3           60.0          NaN           0             0           0
# 4         1359.0        952.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1           167
# 1           0       0                0            66
# 2           0       0                0             0
# 3           0       0                0             0
# 4           0       0                0             0

# %% [markdown]
# # **price**

# %%
# Clean the 'area' column: remove non-numeric characters and convert to float
df['area'] = pd.to_numeric(df['area'], errors='coerce')

# Now plot
plt.figure(figsize=(12,8))
sns.scatterplot(data=df[df['area'] < 10000], x='area', y='price', hue='bedRoom')
plt.title("Scatter plot of Area vs Price colored by Bedroom Count")
plt.xlabel("Area (sq.ft)")
plt.ylabel("Price (crores)")
plt.show()

# %%
# Make sure 'area' is numeric
df['area'] = pd.to_numeric(df['area'], errors='coerce')

# Create the scatter plot
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df[df['area'] < 10000], 
    x='area', 
    y='price', 
    hue='agePossession'
)
plt.title("Area vs Price colored by Age of Possession")
plt.xlabel("Area (sq.ft)")
plt.ylabel("Price (crores)")
plt.show()

# %%
# Ensure 'area' is numeric
df['area'] = pd.to_numeric(df['area'], errors='coerce')

# Drop NaNs if needed
plot_df = df[df['area'] < 10000].copy()
plot_df['furnishing_type'] = plot_df['furnishing_type'].astype('category')

plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=plot_df,
    x='area',
    y='price',
    hue='furnishing_type'
)
plt.title("Price vs Area Colored by Furnishing Type")
plt.xlabel("Area (sq.ft)")
plt.ylabel("Price (crores)")
plt.show()

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(data=df, x='luxury_score', y='price')
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# # **correlation**

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 2
#       1 plt.figure(figsize=(8,8))
# ----> 2 sns.heatmap(df.corr())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'flat'

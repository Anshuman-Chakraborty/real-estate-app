# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
df = pd.read_csv('../processed_data/gurgaon_properties_post_feature_selection_v2.csv')

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat  sector 108   3.95      3.0       5.0       2    New Property
# 1         house   sector 33  11.50      5.0       6.0      3+  Relatively New
# 2         house   sector 13   4.50      4.0       5.0       2    Old Property
# 3          flat  sector 106   1.35      4.0       3.0       3    Old Property
# 4          flat  sector 37c   1.22      3.0       4.0       3  Relatively New
#
#    built_up_area  servant room  store room  furnishing_type luxury_category  \
# 0    2343.101198           1.0         0.0              1.0          Medium
# 1    4680.000000           1.0         0.0              1.0          Medium
# 2    4950.000000           0.0         0.0              1.0             Low
# 3    1678.000000           1.0         0.0              1.0          Medium
# 4    1665.000000           0.0         0.0              1.0          Medium
#
#   floor_category
# 0     High Floor
# 1      Mid Floor
# 2      Low Floor
# 3     High Floor
# 4      Mid Floor

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 1.0    2316
# 2.0    1013
# 0.0     189
# Name: count, dtype: int64

# %%
# 0 -> unfurnished
# 1 -> semifurnished
# 2 -> furnished
df['furnishing_type'] = df['furnishing_type'].replace({0.0:'unfurnished',1.0:'semifurnished',2.0:'furnished'})

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat  sector 108   3.95      3.0       5.0       2    New Property
# 1         house   sector 33  11.50      5.0       6.0      3+  Relatively New
# 2         house   sector 13   4.50      4.0       5.0       2    Old Property
# 3          flat  sector 106   1.35      4.0       3.0       3    Old Property
# 4          flat  sector 37c   1.22      3.0       4.0       3  Relatively New
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0    2343.101198           1.0         0.0   semifurnished          Medium
# 1    4680.000000           1.0         0.0   semifurnished          Medium
# 2    4950.000000           0.0         0.0   semifurnished             Low
# 3    1678.000000           1.0         0.0   semifurnished          Medium
# 4    1665.000000           0.0         0.0   semifurnished          Medium
#
#   floor_category
# 0     High Floor
# 1      Mid Floor
# 2      Low Floor
# 3     High Floor
# 4      Mid Floor

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
# Applying the log1p transformation to the target variable
y_transformed = np.log1p(y)

# %% [markdown]
# # **Ordinal Encoding**

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (0.7169418029987584, 0.058677286404436334)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.8511539862878427

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\anshuman\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\anshuman\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\anshuman\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
# Basic regressors from sklearn
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (
    RandomForestRegressor,
    ExtraTreesRegressor,
    GradientBoostingRegressor,
    AdaBoostRegressor
)
from sklearn.neural_network import MLPRegressor

# XGBoost regressor
from xgboost import XGBRegressor

model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))
# Out:
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
model_output
# Out:
# [['linear_reg', 0.7169418029987584, 0.8511539862878427],
#  ['svr', 0.7503439494797759, 0.8601210242198963],
#  ['ridge', 0.7169491896651573, 0.8513697318000162],
#  ['LASSO', 0.05151220006292094, 1.5200372107524673],
#  ['decision tree', 0.7813624284032722, 0.6676069234595329],
#  ['random forest', 0.8817250734334751, 0.5816937819469922],
#  ['extra trees', 0.8707631012828708, 0.6077885846964126],
#  ['gradient boosting', 0.8758744841451357, 0.6074078345278575],
#  ['adaboost', 0.7542459566393761, 0.8453971468499394],
#  ['mlp', 0.8121907621181219, 0.7476513030809732],
#  ['xgboost', 0.8907359239061708, 0.5446795256190341]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.890736  0.544680
# 5       random forest  0.881725  0.581694
# 7   gradient boosting  0.875874  0.607408
# 6         extra trees  0.870763  0.607789
# 4       decision tree  0.781362  0.667607
# 9                 mlp  0.812191  0.747651
# 8            adaboost  0.754246  0.845397
# 0          linear_reg  0.716942  0.851154
# 2               ridge  0.716949  0.851370
# 1                 svr  0.750344  0.860121
# 3               LASSO  0.051512  1.520037

# %% [markdown]
# # **OneHotEncoding**

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',handle_unknown='ignore'),['sector','agePossession','furnishing_type'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
# Out:
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
scores.mean()
# Out:
# 0.8448655997781598

# %%
scores.std()
# Out:
# 0.03340492588919986

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sector', 'agePossession',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.6222598635109029

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))
# Out:
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.896416  0.506411
# 5       random forest  0.894133  0.533980
# 10            xgboost  0.897572  0.538346
# 9                 mlp  0.870720  0.581080
# 7   gradient boosting  0.878839  0.598516
# 0          linear_reg  0.844866  0.622260
# 2               ridge  0.845329  0.623852
# 4       decision tree  0.824296  0.627691
# 8            adaboost  0.759547  0.829667
# 1                 svr  0.754422  0.858786
# 3               LASSO  0.051512  1.520037

# %% [markdown]
# # **OneHotEncoding With PCA**

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',handle_unknown='ignore',sparse_output=False),['sector','agePossession'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=0.95)),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
# Out:
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
scores.mean()
# Out:
# 0.05424165605129007

# %%
scores.std()
# Out:
# 0.010737632836479025

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('pca', PCA(n_components=0.95)),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))
# Out:
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 5       random forest  0.751859  0.702313
# 6         extra trees  0.725391  0.743975
# 4       decision tree  0.678491  0.786738
# 10            xgboost  0.614989  0.900044
# 7   gradient boosting  0.612768  0.982992
# 1                 svr  0.226657  1.342662
# 8            adaboost  0.309238  1.348752
# 9                 mlp  0.218630  1.433409
# 3               LASSO  0.051697  1.519945
# 2               ridge  0.054242  1.521206
# 0          linear_reg  0.054242  1.521206

# %% [markdown]
# # **Target Encoder**

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\anshuman\anaconda3\lib\site-packages (2.6.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\anshuman\anaconda3\lib\site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\anshuman\anaconda3\lib\site-packages (from category_encoders) (1.3.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\anshuman\anaconda3\lib\site-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\anshuman\anaconda3\lib\site-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\anshuman\anaconda3\lib\site-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\anshuman\anaconda3\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anshuman\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anshuman\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anshuman\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in c:\users\anshuman\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\anshuman\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anshuman\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\anshuman\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (23.2)

# %%
# Install category_encoders (run only once in your notebook or terminal)
# !pip install category_encoders

import category_encoders as ce
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, cross_val_score

# Define all categorical columns
ordinal_cols = ['property_type', 'balcony', 'furnishing_type', 'luxury_category', 'floor_category']
onehot_cols = ['agePossession']
targetenc_cols = ['sector']
numeric_cols = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']

# Wrap TargetEncoder in a pipeline to make it work with ColumnTransformer
target_enc_pipeline = Pipeline([
    ('target', ce.TargetEncoder())
])

# Column Transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('ord', OrdinalEncoder(), ordinal_cols),
        ('ohe', OneHotEncoder(drop='first', sparse_output=False), onehot_cols),
        ('target', target_enc_pipeline, targetenc_cols)
    ],
    remainder='passthrough'
)

# Full Pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# Cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
# Out:
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)

# %%
scores.mean(),scores.std()
# Out:
# (0.8148380597236423, 0.03786582209387001)

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))
# Out:
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# ...
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)
# C:\Users\ANSHUMAN\anaconda3\Lib\site-packages\category_encoders\ordinal.py:210: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[column].fillna(-1, inplace=True)

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 5       random forest  0.894345  0.510744
# 6         extra trees  0.891471  0.524572
# 10            xgboost  0.892486  0.529164
# 7   gradient boosting  0.886336  0.580152
# 1                 svr  0.864195  0.660390
# 9                 mlp  0.855142  0.663467
# 4       decision tree  0.803793  0.666563
# 0          linear_reg  0.814838  0.683182
# 2               ridge  0.814862  0.683307
# 8            adaboost  0.819675  0.769714
# 3               LASSO -0.005227  1.554330

# %% [markdown]
# # **Hyperparameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor

# Define categorical columns
ordinal_cols = ['property_type', 'balcony', 'furnishing_type', 'luxury_category', 'floor_category']
onehot_cols = ['agePossession']
numeric_cols = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']

# All categorical columns MUST be handled — do NOT leave any raw string column for passthrough
# 'sector' is now included only once and encoded using OrdinalEncoder
# You can also OneHotEncode it if it's non-ordinal
categorical_cols = ordinal_cols + ['sector']

# Column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat_ord', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), categorical_cols),
        ('cat_ohe', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'), onehot_cols)
    ],
    remainder='drop'  # Do not passthrough anything unprocessed
)

# Pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=42))
])

# GridSearch parameter grid
param_grid = {
    'regressor__n_estimators': [50, 100, 200],
    'regressor__max_depth': [None, 10, 20],
    'regressor__max_samples': [0.25, 0.5, 1.0],
    'regressor__max_features': ['sqrt', 'log2']
}

# Cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# Grid search (keep n_jobs=1 to avoid pickling issues in Jupyter)
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=1, verbose=4)

# Fit
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 54 candidates, totalling 540 fits
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.825 total time=   0.3s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.824 total time=   0.2s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.845 total time=   0.2s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.860 total time=   0.2s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.837 total time=   0.3s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.866 total time=   0.3s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.837 total time=   0.3s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.853 total time=   0.3s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.863 total time=   0.4s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.864 total time=   0.3s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.831 total time=   0.6s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.836 total time=   0.5s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.844 total time=   0.4s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.869 total time=   0.4s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.842 total time=   0.4s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.872 total time=   0.4s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.836 total time=   0.4s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.859 total time=   0.4s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.863 total time=   0.4s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.865 total time=   0.4s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.832 total time=   0.9s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.834 total time=   0.8s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.846 total time=   0.9s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.870 total time=   0.8s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.842 total time=   1.1s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.873 total time=   1.1s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.833 total time=   0.9s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.862 total time=   0.9s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.865 total time=   0.8s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.862 total time=   0.9s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.836 total time=   0.3s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.839 total time=   0.3s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.859 total time=   0.3s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.879 total time=   0.3s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.850 total time=   0.3s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.877 total time=   0.3s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.846 total time=   0.3s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.861 total time=   0.4s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.876 total time=   0.5s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.870 total time=   0.3s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.841 total time=   0.7s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.842 total time=   0.6s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.861 total time=   0.7s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.885 total time=   0.7s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.853 total time=   0.7s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.883 total time=   0.6s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.845 total time=   0.6s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.868 total time=   0.7s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.873 total time=   0.7s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.872 total time=   0.7s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.842 total time=   1.4s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.845 total time=   1.6s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.857 total time=   1.4s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.884 total time=   1.4s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.853 total time=   1.4s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.882 total time=   1.5s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.844 total time=   1.5s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.870 total time=   1.5s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.875 total time=   1.5s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.871 total time=   1.4s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.845 total time=   0.5s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.846 total time=   0.5s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.862 total time=   0.5s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.884 total time=   0.5s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.859 total time=   0.5s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.880 total time=   0.5s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.851 total time=   0.5s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.876 total time=   0.5s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.876 total time=   0.5s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.870 total time=   0.5s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.852 total time=   1.2s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.847 total time=   1.1s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.869 total time=   1.0s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.892 total time=   1.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.862 total time=   1.0s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.881 total time=   1.0s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.853 total time=   1.1s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.878 total time=   1.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.875 total time=   1.0s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.877 total time=   1.1s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.852 total time=   2.2s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.849 total time=   2.2s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.870 total time=   2.1s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.894 total time=   2.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.858 total time=   2.2s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.884 total time=   2.1s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.856 total time=   2.2s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.878 total time=   2.2s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.879 total time=   2.2s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.878 total time=   2.1s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.825 total time=   0.2s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.824 total time=   0.2s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.845 total time=   0.2s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.860 total time=   0.2s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.837 total time=   0.1s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.866 total time=   0.2s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.837 total time=   0.2s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.853 total time=   0.1s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.863 total time=   0.2s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.864 total time=   0.1s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.831 total time=   0.4s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.836 total time=   0.4s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.844 total time=   0.4s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.869 total time=   0.4s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.842 total time=   0.4s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.872 total time=   0.4s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.836 total time=   0.4s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.859 total time=   0.4s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.863 total time=   0.5s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.865 total time=   0.7s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.832 total time=   0.9s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.834 total time=   0.9s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.846 total time=   0.9s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.870 total time=   1.0s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.842 total time=   0.9s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.873 total time=   0.9s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.833 total time=   0.8s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.862 total time=   0.9s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.865 total time=   0.9s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.862 total time=   0.9s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.836 total time=   0.3s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.839 total time=   0.3s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.859 total time=   0.3s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.879 total time=   0.3s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.850 total time=   0.3s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.877 total time=   0.3s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.846 total time=   0.3s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.861 total time=   0.3s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.876 total time=   0.3s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.870 total time=   0.3s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.841 total time=   0.7s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.842 total time=   0.7s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.861 total time=   0.7s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.885 total time=   0.6s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.853 total time=   0.6s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.883 total time=   0.7s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.845 total time=   0.9s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.868 total time=   0.6s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.873 total time=   0.8s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.872 total time=   0.6s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.842 total time=   1.6s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.845 total time=   1.4s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.857 total time=   1.4s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.884 total time=   1.4s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.853 total time=   1.4s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.882 total time=   1.6s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.844 total time=   1.4s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.870 total time=   1.4s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.875 total time=   1.6s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.871 total time=   1.4s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.845 total time=   0.5s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.846 total time=   0.5s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.862 total time=   0.5s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.884 total time=   0.5s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.859 total time=   0.5s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.880 total time=   0.5s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.851 total time=   0.5s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.876 total time=   0.5s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.876 total time=   0.5s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.870 total time=   0.5s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.852 total time=   1.0s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.847 total time=   1.4s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.869 total time=   1.1s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.892 total time=   1.1s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.862 total time=   1.1s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.881 total time=   1.1s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.853 total time=   1.1s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.878 total time=   1.0s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.875 total time=   1.0s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.877 total time=   1.1s
# [CV 1/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.852 total time=   2.1s
# [CV 2/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.849 total time=   2.1s
# [CV 3/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.870 total time=   2.3s
# [CV 4/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.894 total time=   2.1s
# [CV 5/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.858 total time=   2.1s
# [CV 6/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.884 total time=   2.1s
# [CV 7/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.856 total time=   2.2s
# [CV 8/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.878 total time=   2.2s
# [CV 9/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.879 total time=   2.3s
# [CV 10/10] END regressor__max_depth=None, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.878 total time=   2.2s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.823 total time=   0.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.820 total time=   0.1s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.828 total time=   0.1s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.865 total time=   0.1s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.828 total time=   0.1s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.863 total time=   0.2s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.809 total time=   0.1s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.843 total time=   0.1s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.849 total time=   0.1s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.847 total time=   0.1s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.826 total time=   0.3s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.823 total time=   0.2s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.836 total time=   0.2s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.869 total time=   0.2s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.832 total time=   0.2s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.864 total time=   0.2s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.818 total time=   0.2s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.847 total time=   0.2s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.856 total time=   0.3s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.853 total time=   0.3s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.821 total time=   0.8s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.826 total time=   0.6s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.836 total time=   0.6s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.866 total time=   0.6s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.831 total time=   0.6s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.865 total time=   0.6s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.820 total time=   0.5s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.850 total time=   0.6s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.857 total time=   0.7s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.854 total time=   0.5s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.826 total time=   0.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.829 total time=   0.2s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.841 total time=   0.2s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.865 total time=   0.3s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.839 total time=   0.1s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.869 total time=   0.1s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.831 total time=   0.1s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.855 total time=   0.1s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.857 total time=   0.1s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.850 total time=   0.1s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.832 total time=   0.4s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.834 total time=   0.3s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.845 total time=   0.4s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.870 total time=   0.3s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.842 total time=   0.3s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.873 total time=   0.4s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.831 total time=   0.3s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.856 total time=   0.3s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.861 total time=   0.3s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.858 total time=   0.3s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.830 total time=   0.8s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.833 total time=   0.8s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.845 total time=   0.8s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.873 total time=   0.8s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.838 total time=   0.9s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.871 total time=   0.8s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.832 total time=   0.8s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.857 total time=   0.8s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.862 total time=   0.8s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.860 total time=   0.8s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.829 total time=   0.2s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.824 total time=   0.2s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.851 total time=   0.2s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.871 total time=   0.2s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.833 total time=   0.2s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.871 total time=   0.3s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.833 total time=   0.2s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.858 total time=   0.2s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.860 total time=   0.2s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.865 total time=   0.2s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.830 total time=   0.5s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.833 total time=   0.4s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.852 total time=   0.5s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.875 total time=   0.5s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.840 total time=   0.5s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.873 total time=   0.4s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.834 total time=   0.7s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.857 total time=   0.5s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.861 total time=   0.4s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.868 total time=   0.4s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.831 total time=   1.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.836 total time=   1.0s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.852 total time=   1.1s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.875 total time=   1.0s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.840 total time=   0.9s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.874 total time=   1.1s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.834 total time=   1.0s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.860 total time=   0.9s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.864 total time=   1.0s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=sqrt, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.867 total time=   1.0s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.823 total time=   0.1s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.820 total time=   0.1s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.828 total time=   0.1s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.865 total time=   0.1s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.828 total time=   0.1s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.863 total time=   0.1s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.809 total time=   0.2s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.843 total time=   0.1s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.849 total time=   0.1s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.847 total time=   0.1s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.826 total time=   0.4s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.823 total time=   0.3s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.836 total time=   0.2s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.869 total time=   0.2s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.832 total time=   0.2s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.864 total time=   0.2s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.818 total time=   0.3s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.847 total time=   0.3s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.856 total time=   0.3s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.853 total time=   0.2s
# [CV 1/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.821 total time=   0.6s
# [CV 2/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.826 total time=   0.6s
# [CV 3/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.836 total time=   0.5s
# [CV 4/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.866 total time=   0.6s
# [CV 5/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.831 total time=   0.6s
# [CV 6/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.865 total time=   0.6s
# [CV 7/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.820 total time=   0.6s
# [CV 8/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.850 total time=   0.5s
# [CV 9/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.857 total time=   0.5s
# [CV 10/10] END regressor__max_depth=10, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.854 total time=   0.6s
# ...
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.840 total time=   0.2s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.871 total time=   0.2s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.838 total time=   0.2s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.853 total time=   0.2s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.867 total time=   0.2s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=50;, score=0.863 total time=   0.2s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.831 total time=   0.4s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.837 total time=   0.4s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.845 total time=   0.4s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.872 total time=   0.4s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.843 total time=   0.4s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.874 total time=   0.5s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.835 total time=   0.4s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.858 total time=   0.4s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.865 total time=   0.6s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=100;, score=0.864 total time=   0.4s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.831 total time=   0.9s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.833 total time=   0.9s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.848 total time=   0.8s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.872 total time=   0.9s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.842 total time=   0.9s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.873 total time=   1.1s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.834 total time=   0.9s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.860 total time=   0.9s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.865 total time=   0.9s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.25, regressor__n_estimators=200;, score=0.862 total time=   0.9s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.839 total time=   0.3s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.839 total time=   0.3s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.862 total time=   0.3s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.880 total time=   0.4s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.848 total time=   0.3s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.875 total time=   0.3s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.845 total time=   0.4s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.862 total time=   0.3s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.869 total time=   0.3s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=50;, score=0.867 total time=   0.3s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.841 total time=   0.8s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.843 total time=   0.7s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.862 total time=   1.2s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.882 total time=   1.5s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.848 total time=   1.0s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.879 total time=   1.4s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.849 total time=   1.5s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.870 total time=   1.7s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.876 total time=   0.9s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=100;, score=0.870 total time=   0.9s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.842 total time=   1.9s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.841 total time=   2.3s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.862 total time=   1.7s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.883 total time=   1.8s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.851 total time=   1.5s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.881 total time=   1.5s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.849 total time=   1.7s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.872 total time=   1.5s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.874 total time=   1.5s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=0.5, regressor__n_estimators=200;, score=0.874 total time=   1.6s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.845 total time=   0.5s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.844 total time=   0.6s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.870 total time=   0.4s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.889 total time=   0.5s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.854 total time=   0.6s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.878 total time=   0.6s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.849 total time=   0.6s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.872 total time=   0.5s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.876 total time=   0.5s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=50;, score=0.881 total time=   0.7s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.847 total time=   1.6s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.848 total time=   3.0s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.869 total time=   2.7s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.894 total time=   2.2s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.861 total time=   2.0s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.882 total time=   2.0s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.852 total time=   1.9s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.875 total time=   2.1s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.880 total time=   1.9s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=100;, score=0.880 total time=   2.0s
# [CV 1/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.850 total time=   4.0s
# [CV 2/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.851 total time=   4.3s
# [CV 3/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.872 total time=   4.2s
# [CV 4/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.895 total time=   3.8s
# [CV 5/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.859 total time=   4.2s
# [CV 6/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.885 total time=   4.1s
# [CV 7/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.855 total time=   3.7s
# [CV 8/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.877 total time=   3.7s
# [CV 9/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.881 total time=   3.8s
# [CV 10/10] END regressor__max_depth=20, regressor__max_features=log2, regressor__max_samples=1.0, regressor__n_estimators=200;, score=0.881 total time=   3.9s
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedRoom',
#                                                                           'bathroom',
#                                                                           'built_up_area',
#                                                                           'servant '
#                                                                           'room',
#                                                                           'store '
#                                                                           'room']),
#                                                                         ('cat_ord',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['property_type',
#                                                                           'balcony',
#                                                                           'furnishing_...
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['agePossession'])])),
#                                        ('regressor',
#                                         RandomForestRegressor(random_state=42))]),
#              n_jobs=1,
#              param_grid={'regressor__max_depth': [None, 10, 20],
#                          'regressor__max_features': ['sqrt', 'log2'],
#                          'regressor__max_samples': [0.25, 0.5, 1.0],
#                          'regressor__n_estimators': [50, 100, 200]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
search.best_params_
# Out:
# {'regressor__max_depth': 20,
#  'regressor__max_features': 'sqrt',
#  'regressor__max_samples': 1.0,
#  'regressor__n_estimators': 200}

# %%
search.best_score_
# Out:
# 0.8705765021812211

# %%
final_pipe.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat_ord',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'balcony',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category',
#                                                    'sector']),
#                                                  ('cat_ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['agePossession'])])),
#                 ('regressor',
#                  RandomForestRegressor(max_depth=20, max_features='sqrt',
#                                        max_samples=1.0, n_estimators=200,
#                                        random_state=42))])

# %% [markdown]
# # **Exporting the model**

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

# Define your categorical columns correctly
ordinal_cols = ['property_type', 'balcony', 'furnishing_type', 'luxury_category', 'floor_category']
onehot_cols = ['sector', 'agePossession']
numeric_cols = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']

# Build the ColumnTransformer safely
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat_ord', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ordinal_cols),
        ('cat_ohe', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'), onehot_cols)
    ],
    remainder='drop'  # ensures only encoded/scaled data is passed
)

# Final pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=200, random_state=42))
])

# Fit the model
pipeline.fit(X, y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat_ord',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'balcony',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat_ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['sector',
#                                                    'agePossession'])])),
#                 ('regressor',
#                  RandomForestRegressor(n_estimators=200, random_state=42))])

# %%
import pickle

with open('pipeline.pkl', 'wb') as file:
    pickle.dump(pipeline, file)

# %%
with open('df.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
X
# Out:
#      property_type      sector  bedRoom  bathroom balcony   agePossession  \
# 0             flat  sector 108      3.0       5.0       2    New Property
# 1            house   sector 33      5.0       6.0      3+  Relatively New
# 2            house   sector 13      4.0       5.0       2    Old Property
# 3             flat  sector 106      4.0       3.0       3    Old Property
# 4             flat  sector 37c      3.0       4.0       3  Relatively New
# ...            ...         ...      ...       ...     ...             ...
# 3513          flat   sector 39      5.0       4.0       3    Old Property
# 3514          flat   sector 50      3.0       4.0      3+  Moderately Old
# 3515         house   sector 38      4.0       9.0      3+  Relatively New
# 3516          flat  sector 108      3.0       3.0       3  Relatively New
# 3517          flat   sector 90      4.0       5.0       2    New Property
#
#       built_up_area  servant room  store room furnishing_type luxury_category  \
# 0       2343.101198           1.0         0.0   semifurnished          Medium
# 1       4680.000000           1.0         0.0   semifurnished          Medium
# 2       4950.000000           0.0         0.0   semifurnished             Low
# 3       1678.000000           1.0         0.0   semifurnished          Medium
# 4       1665.000000           0.0         0.0   semifurnished          Medium
# ...             ...           ...         ...             ...             ...
# 3513    3556.000000           1.0         0.0     unfurnished             Low
# 3514    1870.000000           1.0         0.0       furnished            High
# 3515    4800.000000           0.0         1.0       furnished            High
# 3516    1711.000000           0.0         1.0       furnished            High
# 3517    2248.000000           1.0         0.0   semifurnished          Medium
#
#      floor_category
# 0        High Floor
# 1         Mid Floor
# 2         Low Floor
# 3        High Floor
# 4         Mid Floor
# ...             ...
# 3513      Mid Floor
# 3514      Mid Floor
# 3515      Low Floor
# 3516     High Floor
# 3517      Mid Floor
#
# [3518 rows x 12 columns]

# %% [markdown]
# # **Trying out the predictions**

# %%
X.columns
# Out:
# Index(['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
#        'agePossession', 'built_up_area', 'servant room', 'store room',
#        'furnishing_type', 'luxury_category', 'floor_category'],
#       dtype='object')

# %%
X.iloc[0].values
# Out:
# array(['flat', 'sector 108', 3.0, 5.0, '2', 'New Property',
#        2343.101198244157, 1.0, 0.0, 'semifurnished', 'Medium',
#        'High Floor'], dtype=object)

# %%
data = [['house', 'sector 102', 4, 3, '3+', 'New Property', 2750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
       'agePossession', 'built_up_area', 'servant room', 'store room',
       'furnishing_type', 'luxury_category', 'floor_category']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df
# Out:
#   property_type      sector  bedRoom  bathroom balcony agePossession  \
# 0         house  sector 102        4         3      3+  New Property
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0           2750             0           0     unfurnished             Low
#
#   floor_category
# 0      Low Floor

# %%
np.expm1(pipeline.predict(one_df))
# Out:
# array([4.47149288])

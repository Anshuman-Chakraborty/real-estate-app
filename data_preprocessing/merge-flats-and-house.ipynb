# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('../processed_data/flats_cleaned.csv')
houses = pd.read_csv('../processed_data/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0                4 BHK Flat in Sector 54 Gurgaon          flat
# 1               2 BHK Flat in Sector 37C Gurgaon          flat
# 2  1 Bedroom House for sale in Sector 3A Gurgaon         house
# 3        7 Bedroom House for sale in DLF Phase 3         house
# 4               3 BHK Flat in Sector 106 Gurgaon          flat
#
#                           society  price  price_per_sq_ft  \
# 0                 dlf the belaire  10.00          24557.0
# 1              imperia the esfera   0.95           5703.0
# 2                     independent   0.60           6000.0
# 3  u block dlf phase 3 road no 21   1.60          29630.0
# 4                     mrg skyline   1.82          13392.0
#
#                        area  \
# 0               4072.158651
# 1               1665.789935
# 2  (93 sq.m.) Built-up Area
# 3      (50 sq.m.) Plot Area
# 4               1359.020311
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4072(378.3 sq.m.)Built Up ...        4         5
# 1                  Built Up area: 1578 (146.6 sq.m.)        2         2
# 2                   Built Up area: 1000 (92.9 sq.m.)        1         1
# 3                          Plot area 60(50.17 sq.m.)        7         5
# 4  Built Up area: 1359 (126.26 sq.m.)Carpet area:...        3         2
#
#   balcony additionalRoom                                            address  \
# 0      3+   servant room                Sector 54 Gurgaon, Gurgaon, Haryana
# 1       0   servant room               Sector 37C Gurgaon, Gurgaon, Haryana
# 2       0  not available  Laxman Vihar, Sector 3a, Gurgaon, Sector 3A Gu...
# 3      3+  not available            21 By 24, DLF Phase 3, Gurgaon, Haryana
# 4       2  not available   Sector 106, Sector 106 Gurgaon, Gurgaon, Haryana
#
#    floorNum facing       agePossession  \
# 0      17.0  North    5 to 10 Year Old
# 1      17.0    NaN  Under Construction
# 2       1.0    NaN           undefined
# 3       4.0    NaN        10+ Year Old
# 4       4.0   East           undefined
#
#                                      nearbyLocations  \
# 0  ['Sector 42-43 Metro station', 'Horizon 1 Mall...
# 1  ['Approved Sector 37 Mero Station', 'Esplanade...
# 2  ['Chintapurni Mandir', 'State bank ATM', 'Prat...
# 3  ['Dlf phase 3 metro station', 'Micromax moulsa...
# 4  ['Chintapurni Mandir', 'State bank ATM', 'R K ...
#
#                                          description  \
# 0  Available for sale 4bhk plus servant room semi...
# 1  2 bath, unfurnished, 17th floor (Of 17), at se...
# 2  Check out this 4 bhk independent house for sal...
# 3  Property is situated in dlf phase 3 well conne...
# 4  Comming soon sec -106luxury floors just 0 km f...
#
#                                       furnishDetails  \
# 0  ['1 Water Purifier', '7 Fan', '1 Fridge', '1 E...
# 1                                                NaN
# 2  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3                                                NaN
# 4  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
#
#                                             features  \
# 0  ['Centrally Air Conditioned', 'Water purifier'...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction5 out ...
# 1  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 4                                                NaN

# %%
df.to_csv('../processed_data/gurgaon_properties.csv',index=False)

# %%
df.shape
# Out:
# (3961, 20)

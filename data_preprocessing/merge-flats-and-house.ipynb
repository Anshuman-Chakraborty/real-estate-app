# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('../processed_data/flats_cleaned.csv')
houses = pd.read_csv('../processed_data/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                        property_name property_type  \
# 0                    3 BHK Flat in Sector 92 Gurgaon          flat
# 1                    2 BHK Flat in Sector 86 Gurgaon          flat
# 2  4 Bedroom House for sale in C Block Sushant Lo...         house
# 3                   2 BHK Flat in Sector 107 Gurgaon          flat
# 4                   3 BHK Flat in Sector 82A Gurgaon          flat
#
#                    society  price  price_per_sq_ft         area  \
# 0  sare green parc phase 3   0.70           5279.0  1326.008714
# 1         ansal heights 86   0.87           5367.0  1621.017328
# 2              independent   5.75              NaN  1935.000000
# 3            m3m woodshire   0.88           6442.0  1366.035393
# 4           dlf the primus   1.87          10394.0  1799.114874
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1326(123.19 sq.m.)Built Up...        3         2
# 1             Super Built up area 1360(126.35 sq.m.)        2         2
# 2                        Plot area 215(179.77 sq.m.)        4         4
# 3             Super Built up area 1366(126.91 sq.m.)        2         2
# 4  Super Built up area 1799(167.13 sq.m.)Carpet a...        3         3
#
#   balcony  ...                                        address floorNum  \
# 0       2  ...            Sector 92 Gurgaon, Gurgaon, Haryana      4.0
# 1       1  ...    H-1203, Sector 86 Gurgaon, Gurgaon, Haryana     12.0
# 2       2  ...  C Block Sushant Lok Phase 1, Gurgaon, Haryana      2.0
# 3      3+  ...           Sector 107 Gurgaon, Gurgaon, Haryana      3.0
# 4       3  ...      198, Sector 82A Gurgaon, Gurgaon, Haryana     31.0
#
#        facing     agePossession  \
# 0         NaN   1 to 5 Year Old
# 1  North-East   0 to 1 Year Old
# 2       North      10+ Year Old
# 3        East   1 to 5 Year Old
# 4        East  5 to 10 Year Old
#
#                                      nearbyLocations  \
# 0  ['Huda Metro Station', 'Sector Road', 'Delhi-J...
# 1  ['IRIS Broadway Mall', 'Delhi Jaipur Expresswa...
# 2  ['Sector 42-43 metro station', 'Huda city cent...
# 3  ['Signum 107', 'Nora Solomon Medicenter', 'Ind...
# 4  ['Sapphire 83', 'NH 48', 'Cambridge Montessori...
#
#                                          description  \
# 0                    Property at 4th floor ne facing
# 1  Very good location. Near to nh-8 and dlf sky-C...
# 2  North facing property\n100 meter from vaipar k...
# 3  Corner and airy flat with ample sunlight throu...
# 4  This 3 bhk apartment is available for sale in ...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '4 Fan', '1 Exhaust Fan', '2 Ge...
# 1  ['2 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3  ['1 Bed', '5 Fan', '1 Sofa', '10 Light', '3 AC...
# 4                                                NaN
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Intercom Facility', 'Lift(s)', 'Swimming Poo...
# 2  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 3  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 4  ['Power Back-up', 'Intercom Facility', 'Lift(s...
#
#                                               rating price_per_sqft
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...            NaN
# 1  ['Safety4.5 out of 5', 'Lifestyle5 out of 5', ...            NaN
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...        29716.0
# 3  ['Green Area4.5 out of 5', 'Construction5 out ...            NaN
# 4  ['Green Area5 out of 5', 'Construction4.5 out ...            NaN
#
# [5 rows x 21 columns]

# %%
df.to_csv('../processed_data/gurgaon_properties.csv',index=False)

# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('../processed_data/flats_cleaned.csv')
houses = pd.read_csv('../processed_data/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0               3 BHK Flat in Sector 108 Gurgaon          flat
# 1  5 Bedroom House for sale in Sector 33 Gurgaon         house
# 2         4 Bedroom House for sale in Prem Nagar         house
# 3               4 BHK Flat in Sector 106 Gurgaon          flat
# 4               3 BHK Flat in Sector 37C Gurgaon          flat
#
#                     society  price  price_per_sq_ft         area  \
# 0                sobha city   3.95          16858.0  2343.101198
# 1  unitech uniworld resorts  11.50          24573.0  4680.000000
# 2               independent   4.50           9091.0  4950.000000
# 3                paras dews   1.35           8940.0  1510.067114
# 4              corona optus   1.22           6912.0  1765.046296
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 2343(217.67 sq.m.)Carpet a...        3         5
# 1                        Plot area 520(434.79 sq.m.)        5         6
# 2                        Plot area 550(459.87 sq.m.)        4         5
# 3                   Carpet area: 1510 (140.28 sq.m.)        4         3
# 4  Super Built up area 1765(163.97 sq.m.)Built Up...        3         4
#
#   balcony additionalRoom                                     address  \
# 0       2   servant room   114, Sector 108 Gurgaon, Gurgaon, Haryana
# 1      3+   servant room         Sector 33 Gurgaon, Gurgaon, Haryana
# 2       2  not available         339/3, Prem Nagar, Gurgaon, Haryana
# 3       3   servant room  1901, Sector 106 Gurgaon, Gurgaon, Haryana
# 4       3  not available   501, Sector 37C Gurgaon, Gurgaon, Haryana
#
#    floorNum      facing    agePossession  \
# 0      15.0       North  0 to 1 Year Old
# 1       4.0        East  1 to 5 Year Old
# 2       2.0        East     10+ Year Old
# 3      19.0         NaN     10+ Year Old
# 4       5.0  South-East  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Dwarka Sector 21', 'Dwarka Expressway', 'Vas...
# 1  ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stan...
# 2  ['Hanuman Mandir', 'Sheetla Mata Mandir', 'Lot...
# 3  ['MG Road Metro Station', 'NeoSquare Shopping ...
# 4  ['The Esplanade Mall', 'Gurugram Road', 'Delhi...
#
#                                          description  \
# 0  Sobha city is one of the most popular destinat...
# 1  500 sqyd villas with front and rear lawns , pr...
# 2  This property is near main gurugram bus stand....
# 3  Check out this 4 bhk apartment for sale in par...
# 4  This lovely 3 bhk apartment/flat in sector 37c...
#
#                                       furnishDetails  \
# 0  ['5 Geyser', 'No AC', 'No Bed', 'No Chimney', ...
# 1  ['5 Wardrobe', '6 Fan', '18 Light', 'No AC', '...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             features  \
# 0  ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 1  ['Private Garden / Terrace', 'High Ceiling Hei...
# 2                                                NaN
# 3  ['Security / Fire Alarm', 'Intercom Facility',...
# 4  ['Centrally Air Conditioned', 'Water purifier'...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4.5 out of...
# 1  ['Environment3 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3                                                NaN
# 4  ['Green Area5 out of 5', 'Construction4 out of...

# %%
df.to_csv('../processed_data/gurgaon_properties.csv',index=False)

# %%
df.shape
# Out:
# (3961, 20)
